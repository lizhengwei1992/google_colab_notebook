# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/lizhengwei1992/google_colab_notebook/blob/master/my_DeepLab_v3_Demo.ipynb)

# %% [markdown]
# # DeepLab Demo
#
# This demo will demostrate the steps to run deeplab semantic segmentation model on sample input images.

# %%
# !pip install graphviz
# Out:
# Collecting graphviz
#   Downloading https://files.pythonhosted.org/packages/53/39/4ab213673844e0c004bed8a0781a0721a3f6bb23eb8854ee75c236428892/graphviz-0.8.4-py2.py3-none-any.whl
# Installing collected packages: graphviz
# Successfully installed graphviz-0.8.4

# %%
from graphviz import Digraph
def tf_to_dot(graph):
    dot = Digraph()

    for n in graph.as_graph_def().node:
        dot.node(n.name, label=n.name)

        for i in n.input:
            dot.edge(i, n.name)
            
    return dot

# %%
#@title Imports

import os
from io import BytesIO
import tarfile
import tempfile
from six.moves import urllib
import pdb
from matplotlib import gridspec
from matplotlib import pyplot as plt
import numpy as np
from PIL import Image

import tensorflow as tf
print(tf.__version__)
# Out:
# 1.9.0-rc1

# %%
#@title Helper methods


class DeepLabModel(object):
  """Class to load deeplab model and run inference."""

  INPUT_TENSOR_NAME = 'ImageTensor:0'
  OUTPUT_TENSOR_NAME = 'SemanticPredictions:0'
  INPUT_SIZE = 513
  FROZEN_GRAPH_NAME = 'frozen_inference_graph'

  def __init__(self, tarball_path):
    """Creates and loads pretrained deeplab model."""
    self.graph = tf.Graph()
    graph_def = None
    # Extract frozen graph from tar archive.
    print(tarball_path)
    tar_file = tarfile.open(tarball_path)
    for tar_info in tar_file.getmembers():
      print(os.listdir('./'))
      if self.FROZEN_GRAPH_NAME in os.path.basename(tar_info.name):
        file_handle = tar_file.extractfile(tar_info)
        graph_def = tf.GraphDef.FromString(file_handle.read())
        break
    tar_file.close()

    if graph_def is None:
      raise RuntimeError('Cannot find inference graph in tar archive.')

    with self.graph.as_default():
      tf.import_graph_def(graph_def, name='')
#       for op in tf.get_default_graph().get_operations():
#         print (op.values()) 
#     for node in self.graph.as_graph_def().node:
#       print(node.values())
    

     
    self.sess = tf.Session(graph=self.graph)

    # ------------     
    print(tf_to_dot(self.graph))


    
    
    
    
  def run(self, image):
    """Runs inference on a single image.

    Args:
      image: A PIL.Image object, raw input image.

    Returns:
      resized_image: RGB image resized from original input image.
      seg_map: Segmentation map of `resized_image`.
    """
    width, height = image.size
    print(image.size)
    resize_ratio = 1.0 * self.INPUT_SIZE / max(width, height)
    target_size = (int(resize_ratio * width), int(resize_ratio * height))
    resized_image = image.convert('RGB').resize(target_size, Image.ANTIALIAS)
    batch_seg_map = self.sess.run(
        self.OUTPUT_TENSOR_NAME,
        feed_dict={self.INPUT_TENSOR_NAME: [np.asarray(resized_image)]})
    seg_map = batch_seg_map[0]
    print(seg_map.shape)
    return resized_image, seg_map


def create_pascal_label_colormap():
  """Creates a label colormap used in PASCAL VOC segmentation benchmark.

  Returns:
    A Colormap for visualizing segmentation results.
  """
  colormap = np.zeros((256, 3), dtype=int)
  ind = np.arange(256, dtype=int)

  for shift in reversed(range(8)):
    for channel in range(3):
      colormap[:, channel] |= ((ind >> channel) & 1) << shift
    ind >>= 3

  return colormap


def label_to_color_image(label):
  """Adds color defined by the dataset colormap to the label.

  Args:
    label: A 2D array with integer type, storing the segmentation label.

  Returns:
    result: A 2D array with floating type. The element of the array
      is the color indexed by the corresponding element in the input label
      to the PASCAL color map.

  Raises:
    ValueError: If label is not of rank 2 or its value is larger than color
      map maximum entry.
  """
  if label.ndim != 2:
    raise ValueError('Expect 2-D input label')

  colormap = create_pascal_label_colormap()

  if np.max(label) >= len(colormap):
    raise ValueError('label value too large.')

  return colormap[label]


def vis_segmentation(image, seg_map):
  """Visualizes input image, segmentation map and overlay view."""
  plt.figure(figsize=(15, 5))
  grid_spec = gridspec.GridSpec(1, 4, width_ratios=[6, 6, 6, 1])

  plt.subplot(grid_spec[0])
  plt.imshow(image)
  plt.axis('off')
  plt.title('input image')

  plt.subplot(grid_spec[1])
  seg_image = label_to_color_image(seg_map).astype(np.uint8)
  plt.imshow(seg_image)
  plt.axis('off')
  plt.title('segmentation map')

  plt.subplot(grid_spec[2])
  plt.imshow(image)
  plt.imshow(seg_image, alpha=0.7)
  plt.axis('off')
  plt.title('segmentation overlay')

  unique_labels = np.unique(seg_map)
  ax = plt.subplot(grid_spec[3])
  plt.imshow(
      FULL_COLOR_MAP[unique_labels].astype(np.uint8), interpolation='nearest')
  ax.yaxis.tick_right()
  plt.yticks(range(len(unique_labels)), LABEL_NAMES[unique_labels])
  plt.xticks([], [])
  ax.tick_params(width=0.0)
  plt.grid('off')
  plt.show()


LABEL_NAMES = np.asarray([
    'background', 'aeroplane', 'bicycle', 'bird', 'boat', 'bottle', 'bus',
    'car', 'cat', 'chair', 'cow', 'diningtable', 'dog', 'horse', 'motorbike',
    'person', 'pottedplant', 'sheep', 'sofa', 'train', 'tv'
])

FULL_LABEL_MAP = np.arange(len(LABEL_NAMES)).reshape(len(LABEL_NAMES), 1)
FULL_COLOR_MAP = label_to_color_image(FULL_LABEL_MAP)

# %%
#@title Select and download models {display-mode: "form"}

MODEL_NAME = 'mobilenetv2_coco_voctrainaug'  # @param ['mobilenetv2_coco_voctrainaug', 'mobilenetv2_coco_voctrainval', 'xception_coco_voctrainaug', 'xception_coco_voctrainval']

_DOWNLOAD_URL_PREFIX = 'http://download.tensorflow.org/models/'
_MODEL_URLS = {
    'mobilenetv2_coco_voctrainaug':
        'deeplabv3_mnv2_pascal_train_aug_2018_01_29.tar.gz',
    'mobilenetv2_coco_voctrainval':
        'deeplabv3_mnv2_pascal_trainval_2018_01_29.tar.gz',
    'xception_coco_voctrainaug':
        'deeplabv3_pascal_train_aug_2018_01_04.tar.gz',
    'xception_coco_voctrainval':
        'deeplabv3_pascal_trainval_2018_01_04.tar.gz',
}
_TARBALL_NAME = 'deeplab_model.tar.gz'

model_dir = tempfile.mkdtemp()
tf.gfile.MakeDirs(model_dir)

download_path = os.path.join(model_dir, _TARBALL_NAME)
print('downloading model, this might take a while...')
urllib.request.urlretrieve(_DOWNLOAD_URL_PREFIX + _MODEL_URLS[MODEL_NAME],
                   download_path)
print('download completed! loading DeepLab model...')

MODEL = DeepLabModel(download_path)
print('model loaded successfully!')
# Out:
# downloading model, this might take a while...
# download completed! loading DeepLab model...
# /tmp/tmp2c2n9c/deeplab_model.tar.gz
# ['datalab', '.cache', '.local', '.keras', '.forever', '.config', '.ipython']
# ['datalab', '.cache', '.local', '.keras', '.forever', '.config', '.ipython']
# ['datalab', '.cache', '.local', '.keras', '.forever', '.config', '.ipython']
# digraph {
# 	ImageTensor [label=ImageTensor]
# 	Shape [label=Shape]
# 	ImageTensor -> Shape
# 	"strided_slice/stack" [label="strided_slice/stack"]
# 	"strided_slice/stack_1" [label="strided_slice/stack_1"]
# 	"strided_slice/stack_2" [label="strided_slice/stack_2"]
# 	strided_slice [label=strided_slice]
# 	Shape -> strided_slice
# 	"strided_slice/stack" -> strided_slice
# 	"strided_slice/stack_1" -> strided_slice
# 	"strided_slice/stack_2" -> strided_slice
# 	Squeeze [label=Squeeze]
# 	ImageTensor -> Squeeze
# 	Cast [label=Cast]
# 	Squeeze -> Cast
# 	"ToFloat/x" [label="ToFloat/x"]
# 	Shape_1 [label=Shape_1]
# 	Cast -> Shape_1
# 	"strided_slice_1/stack" [label="strided_slice_1/stack"]
# 	"strided_slice_1/stack_1" [label="strided_slice_1/stack_1"]
# 	"strided_slice_1/stack_2" [label="strided_slice_1/stack_2"]
# 	strided_slice_1 [label=strided_slice_1]
# 	Shape_1 -> strided_slice_1
# 	"strided_slice_1/stack" -> strided_slice_1
# 	"strided_slice_1/stack_1" -> strided_slice_1
# 	"strided_slice_1/stack_2" -> strided_slice_1
# 	"strided_slice_2/stack" [label="strided_slice_2/stack"]
# 	"strided_slice_2/stack_1" [label="strided_slice_2/stack_1"]
# 	"strided_slice_2/stack_2" [label="strided_slice_2/stack_2"]
# 	strided_slice_2 [label=strided_slice_2]
# 	Shape_1 -> strided_slice_2
# 	"strided_slice_2/stack" -> strided_slice_2
# 	"strided_slice_2/stack_1" -> strided_slice_2
# 	"strided_slice_2/stack_2" -> strided_slice_2
# 	"ToFloat_1/x" [label="ToFloat_1/x"]
# 	strided_slice_1 -> "ToFloat_1/x"
# 	strided_slice_2 -> "ToFloat_1/x"
# 	ToFloat_1 [label=ToFloat_1]
# 	"ToFloat_1/x" -> ToFloat_1
# 	mul [label=mul]
# 	ToFloat_1 -> mul
# 	"ToFloat/x" -> mul
# 	ToInt32 [label=ToInt32]
# 	mul -> ToInt32
# 	"ExpandDims/dim" [label="ExpandDims/dim"]
# 	ExpandDims [label=ExpandDims]
# 	Cast -> ExpandDims
# 	"ExpandDims/dim" -> ExpandDims
# 	ResizeBilinear [label=ResizeBilinear]
# 	ExpandDims -> ResizeBilinear
# 	ToInt32 -> ResizeBilinear
# 	Squeeze_1 [label=Squeeze_1]
# 	ResizeBilinear -> Squeeze_1
# 	Shape_2 [label=Shape_2]
# 	Squeeze_1 -> Shape_2
# 	"strided_slice_3/stack" [label="strided_slice_3/stack"]
# 	"strided_slice_3/stack_1" [label="strided_slice_3/stack_1"]
# 	"strided_slice_3/stack_2" [label="strided_slice_3/stack_2"]
# 	strided_slice_3 [label=strided_slice_3]
# 	Shape_2 -> strided_slice_3
# 	"strided_slice_3/stack" -> strided_slice_3
# 	"strided_slice_3/stack_1" -> strided_slice_3
# 	"strided_slice_3/stack_2" -> strided_slice_3
# 	"strided_slice_4/stack" [label="strided_slice_4/stack"]
# 	"strided_slice_4/stack_1" [label="strided_slice_4/stack_1"]
# 	"strided_slice_4/stack_2" [label="strided_slice_4/stack_2"]
# 	strided_slice_4 [label=strided_slice_4]
# 	Shape_2 -> strided_slice_4
# 	"strided_slice_4/stack" -> strided_slice_4
# 	"strided_slice_4/stack_1" -> strided_slice_4
# 	"strided_slice_4/stack_2" -> strided_slice_4
# 	"sub/x" [label="sub/x"]
# 	sub [label=sub]
# 	"sub/x" -> sub
# 	strided_slice_3 -> sub
# 	"Maximum/y" [label="Maximum/y"]
# 	Maximum [label=Maximum]
# 	sub -> Maximum
# 	"Maximum/y" -> Maximum
# 	add [label=add]
# 	strided_slice_3 -> add
# 	Maximum -> add
# 	"sub_1/x" [label="sub_1/x"]
# 	sub_1 [label=sub_1]
# 	"sub_1/x" -> sub_1
# 	strided_slice_4 -> sub_1
# 	"Maximum_1/y" [label="Maximum_1/y"]
# 	Maximum_1 [label=Maximum_1]
# 	sub_1 -> Maximum_1
# 	"Maximum_1/y" -> Maximum_1
# 	add_1 [label=add_1]
# 	strided_slice_4 -> add_1
# 	Maximum_1 -> add_1
# 	"Reshape/tensor" [label="Reshape/tensor"]
# 	"Reshape/shape" [label="Reshape/shape"]
# 	Reshape [label=Reshape]
# 	"Reshape/tensor" -> Reshape
# 	"Reshape/shape" -> Reshape
# 	Rank [label=Rank]
# 	"Equal/y" [label="Equal/y"]
# 	Equal [label=Equal]
# 	Rank -> Equal
# 	"Equal/y" -> Equal
# 	"Assert/Assert/data_0" [label="Assert/Assert/data_0"]
# 	"Assert/Assert/data_1" [label="Assert/Assert/data_1"]
# 	"Assert/Assert" [label="Assert/Assert"]
# 	Equal -> "Assert/Assert"
# 	"Assert/Assert/data_0" -> "Assert/Assert"
# 	"Assert/Assert/data_1" -> "Assert/Assert"
# 	Rank -> "Assert/Assert"
# 	sub_2 [label=sub_2]
# 	Squeeze_1 -> sub_2
# 	Reshape -> sub_2
# 	"^Assert/Assert" -> sub_2
# 	Shape_3 [label=Shape_3]
# 	sub_2 -> Shape_3
# 	"strided_slice_5/stack" [label="strided_slice_5/stack"]
# 	"strided_slice_5/stack_1" [label="strided_slice_5/stack_1"]
# 	"strided_slice_5/stack_2" [label="strided_slice_5/stack_2"]
# 	strided_slice_5 [label=strided_slice_5]
# 	Shape_3 -> strided_slice_5
# 	"strided_slice_5/stack" -> strided_slice_5
# 	"strided_slice_5/stack_1" -> strided_slice_5
# 	"strided_slice_5/stack_2" -> strided_slice_5
# 	"strided_slice_6/stack" [label="strided_slice_6/stack"]
# 	"strided_slice_6/stack_1" [label="strided_slice_6/stack_1"]
# 	"strided_slice_6/stack_2" [label="strided_slice_6/stack_2"]
# 	strided_slice_6 [label=strided_slice_6]
# 	Shape_3 -> strided_slice_6
# 	"strided_slice_6/stack" -> strided_slice_6
# 	"strided_slice_6/stack_1" -> strided_slice_6
# 	"strided_slice_6/stack_2" -> strided_slice_6
# 	GreaterEqual [label=GreaterEqual]
# 	add_1 -> GreaterEqual
# 	strided_slice_6 -> GreaterEqual
# 	"Assert_1/Assert/data_0" [label="Assert_1/Assert/data_0"]
# 	"Assert_1/Assert" [label="Assert_1/Assert"]
# 	GreaterEqual -> "Assert_1/Assert"
# 	"Assert_1/Assert/data_0" -> "Assert_1/Assert"
# 	GreaterEqual_1 [label=GreaterEqual_1]
# 	add -> GreaterEqual_1
# 	strided_slice_5 -> GreaterEqual_1
# 	"Assert_2/Assert/data_0" [label="Assert_2/Assert/data_0"]
# 	"Assert_2/Assert" [label="Assert_2/Assert"]
# 	GreaterEqual_1 -> "Assert_2/Assert"
# 	"Assert_2/Assert/data_0" -> "Assert_2/Assert"
# 	"sub_3/y" [label="sub_3/y"]
# 	"^Assert_1/Assert" -> "sub_3/y"
# 	sub_3 [label=sub_3]
# 	add_1 -> sub_3
# 	"sub_3/y" -> sub_3
# 	sub_4 [label=sub_4]
# 	sub_3 -> sub_4
# 	strided_slice_6 -> sub_4
# 	"sub_5/y" [label="sub_5/y"]
# 	"^Assert_2/Assert" -> "sub_5/y"
# 	sub_5 [label=sub_5]
# 	add -> sub_5
# 	"sub_5/y" -> sub_5
# 	sub_6 [label=sub_6]
# 	sub_5 -> sub_6
# 	strided_slice_5 -> sub_6
# 	"GreaterEqual_2/y" [label="GreaterEqual_2/y"]
# 	GreaterEqual_2 [label=GreaterEqual_2]
# 	sub_4 -> GreaterEqual_2
# 	"GreaterEqual_2/y" -> GreaterEqual_2
# 	"GreaterEqual_3/y" [label="GreaterEqual_3/y"]
# 	GreaterEqual_3 [label=GreaterEqual_3]
# 	sub_6 -> GreaterEqual_3
# 	"GreaterEqual_3/y" -> GreaterEqual_3
# 	LogicalAnd [label=LogicalAnd]
# 	GreaterEqual_2 -> LogicalAnd
# 	GreaterEqual_3 -> LogicalAnd
# 	"Assert_3/Assert/data_0" [label="Assert_3/Assert/data_0"]
# 	"Assert_3/Assert" [label="Assert_3/Assert"]
# 	LogicalAnd -> "Assert_3/Assert"
# 	"Assert_3/Assert/data_0" -> "Assert_3/Assert"
# 	"stack/0" [label="stack/0"]
# 	stack [label=stack]
# 	"stack/0" -> stack
# 	sub_6 -> stack
# 	"stack_1/0" [label="stack_1/0"]
# 	stack_1 [label=stack_1]
# 	"stack_1/0" -> stack_1
# 	sub_4 -> stack_1
# 	stack_2 [label=stack_2]
# 	stack_3 [label=stack_3]
# 	stack -> stack_3
# 	stack_1 -> stack_3
# 	stack_2 -> stack_3
# 	"^Assert_3/Assert" -> stack_3
# 	Pad [label=Pad]
# 	sub_2 -> Pad
# 	stack_3 -> Pad
# 	add_2 [label=add_2]
# 	Pad -> add_2
# 	Reshape -> add_2
# 	"ExpandDims_1/dim" [label="ExpandDims_1/dim"]
# 	ExpandDims_1 [label=ExpandDims_1]
# 	add_2 -> ExpandDims_1
# 	"ExpandDims_1/dim" -> ExpandDims_1
# 	"mul_1/x" [label="mul_1/x"]
# 	mul_1 [label=mul_1]
# 	"mul_1/x" -> mul_1
# 	ExpandDims_1 -> mul_1
# 	"sub_7/y" [label="sub_7/y"]
# 	sub_7 [label=sub_7]
# 	mul_1 -> sub_7
# 	"sub_7/y" -> sub_7
# 	"MobilenetV2/Conv/weights" [label="MobilenetV2/Conv/weights"]
# 	"MobilenetV2/Conv/weights/read" [label="MobilenetV2/Conv/weights/read"]
# 	"MobilenetV2/Conv/weights" -> "MobilenetV2/Conv/weights/read"
# 	"MobilenetV2/Conv/Conv2D" [label="MobilenetV2/Conv/Conv2D"]
# 	sub_7 -> "MobilenetV2/Conv/Conv2D"
# 	"MobilenetV2/Conv/weights/read" -> "MobilenetV2/Conv/Conv2D"
# 	"MobilenetV2/Conv/BatchNorm/gamma" [label="MobilenetV2/Conv/BatchNorm/gamma"]
# 	"MobilenetV2/Conv/BatchNorm/gamma/read" [label="MobilenetV2/Conv/BatchNorm/gamma/read"]
# 	"MobilenetV2/Conv/BatchNorm/gamma" -> "MobilenetV2/Conv/BatchNorm/gamma/read"
# 	"MobilenetV2/Conv/BatchNorm/beta" [label="MobilenetV2/Conv/BatchNorm/beta"]
# 	"MobilenetV2/Conv/BatchNorm/beta/read" [label="MobilenetV2/Conv/BatchNorm/beta/read"]
# 	"MobilenetV2/Conv/BatchNorm/beta" -> "MobilenetV2/Conv/BatchNorm/beta/read"
# 	"MobilenetV2/Conv/BatchNorm/moving_mean" [label="MobilenetV2/Conv/BatchNorm/moving_mean"]
# 	"MobilenetV2/Conv/BatchNorm/moving_mean/read" [label="MobilenetV2/Conv/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/Conv/BatchNorm/moving_mean" -> "MobilenetV2/Conv/BatchNorm/moving_mean/read"
# 	"MobilenetV2/Conv/BatchNorm/moving_variance" [label="MobilenetV2/Conv/BatchNorm/moving_variance"]
# 	"MobilenetV2/Conv/BatchNorm/moving_variance/read" [label="MobilenetV2/Conv/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/Conv/BatchNorm/moving_variance" -> "MobilenetV2/Conv/BatchNorm/moving_variance/read"
# 	"MobilenetV2/Conv/BatchNorm/FusedBatchNorm" [label="MobilenetV2/Conv/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/Conv/Conv2D" -> "MobilenetV2/Conv/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/Conv/BatchNorm/gamma/read" -> "MobilenetV2/Conv/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/Conv/BatchNorm/beta/read" -> "MobilenetV2/Conv/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/Conv/BatchNorm/moving_mean/read" -> "MobilenetV2/Conv/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/Conv/BatchNorm/moving_variance/read" -> "MobilenetV2/Conv/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/Conv/Relu6" [label="MobilenetV2/Conv/Relu6"]
# 	"MobilenetV2/Conv/BatchNorm/FusedBatchNorm" -> "MobilenetV2/Conv/Relu6"
# 	"MobilenetV2/expanded_conv/input" [label="MobilenetV2/expanded_conv/input"]
# 	"MobilenetV2/Conv/Relu6" -> "MobilenetV2/expanded_conv/input"
# 	"MobilenetV2/expanded_conv/depthwise/depthwise_weights" [label="MobilenetV2/expanded_conv/depthwise/depthwise_weights"]
# 	"MobilenetV2/expanded_conv/depthwise/depthwise_weights/read" [label="MobilenetV2/expanded_conv/depthwise/depthwise_weights/read"]
# 	"MobilenetV2/expanded_conv/depthwise/depthwise_weights" -> "MobilenetV2/expanded_conv/depthwise/depthwise_weights/read"
# 	"MobilenetV2/expanded_conv/depthwise/depthwise" [label="MobilenetV2/expanded_conv/depthwise/depthwise"]
# 	"MobilenetV2/expanded_conv/input" -> "MobilenetV2/expanded_conv/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv/depthwise/depthwise_weights/read" -> "MobilenetV2/expanded_conv/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/beta" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/beta" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv/depthwise/depthwise" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/depthwise/Relu6" [label="MobilenetV2/expanded_conv/depthwise/Relu6"]
# 	"MobilenetV2/expanded_conv/depthwise/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv/depthwise/Relu6"
# 	"MobilenetV2/expanded_conv/depthwise_output" [label="MobilenetV2/expanded_conv/depthwise_output"]
# 	"MobilenetV2/expanded_conv/depthwise/Relu6" -> "MobilenetV2/expanded_conv/depthwise_output"
# 	"MobilenetV2/expanded_conv/project/weights" [label="MobilenetV2/expanded_conv/project/weights"]
# 	"MobilenetV2/expanded_conv/project/weights/read" [label="MobilenetV2/expanded_conv/project/weights/read"]
# 	"MobilenetV2/expanded_conv/project/weights" -> "MobilenetV2/expanded_conv/project/weights/read"
# 	"MobilenetV2/expanded_conv/project/Conv2D" [label="MobilenetV2/expanded_conv/project/Conv2D"]
# 	"MobilenetV2/expanded_conv/depthwise_output" -> "MobilenetV2/expanded_conv/project/Conv2D"
# 	"MobilenetV2/expanded_conv/project/weights/read" -> "MobilenetV2/expanded_conv/project/Conv2D"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/gamma" [label="MobilenetV2/expanded_conv/project/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv/project/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/gamma" -> "MobilenetV2/expanded_conv/project/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/beta" [label="MobilenetV2/expanded_conv/project/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv/project/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/beta" -> "MobilenetV2/expanded_conv/project/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv/project/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv/project/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv/project/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv/project/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv/project/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv/project/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv/project/Conv2D" -> "MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/project/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv/project/Identity" [label="MobilenetV2/expanded_conv/project/Identity"]
# 	"MobilenetV2/expanded_conv/project/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv/project/Identity"
# 	"MobilenetV2/expanded_conv/output" [label="MobilenetV2/expanded_conv/output"]
# 	"MobilenetV2/expanded_conv/project/Identity" -> "MobilenetV2/expanded_conv/output"
# 	"MobilenetV2/expanded_conv_1/input" [label="MobilenetV2/expanded_conv_1/input"]
# 	"MobilenetV2/expanded_conv/output" -> "MobilenetV2/expanded_conv_1/input"
# 	"MobilenetV2/expanded_conv_1/expand/weights" [label="MobilenetV2/expanded_conv_1/expand/weights"]
# 	"MobilenetV2/expanded_conv_1/expand/weights/read" [label="MobilenetV2/expanded_conv_1/expand/weights/read"]
# 	"MobilenetV2/expanded_conv_1/expand/weights" -> "MobilenetV2/expanded_conv_1/expand/weights/read"
# 	"MobilenetV2/expanded_conv_1/expand/Conv2D" [label="MobilenetV2/expanded_conv_1/expand/Conv2D"]
# 	"MobilenetV2/expanded_conv_1/input" -> "MobilenetV2/expanded_conv_1/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_1/expand/weights/read" -> "MobilenetV2/expanded_conv_1/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/beta" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/beta" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_1/expand/Conv2D" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/expand/Relu6" [label="MobilenetV2/expanded_conv_1/expand/Relu6"]
# 	"MobilenetV2/expanded_conv_1/expand/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_1/expand/Relu6"
# 	"MobilenetV2/expanded_conv_1/expansion_output" [label="MobilenetV2/expanded_conv_1/expansion_output"]
# 	"MobilenetV2/expanded_conv_1/expand/Relu6" -> "MobilenetV2/expanded_conv_1/expansion_output"
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise_weights" [label="MobilenetV2/expanded_conv_1/depthwise/depthwise_weights"]
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/read" [label="MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/read"]
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise_weights" -> "MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/read"
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise" [label="MobilenetV2/expanded_conv_1/depthwise/depthwise"]
# 	"MobilenetV2/expanded_conv_1/expansion_output" -> "MobilenetV2/expanded_conv_1/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise_weights/read" -> "MobilenetV2/expanded_conv_1/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_1/depthwise/depthwise" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/depthwise/Relu6" [label="MobilenetV2/expanded_conv_1/depthwise/Relu6"]
# 	"MobilenetV2/expanded_conv_1/depthwise/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_1/depthwise/Relu6"
# 	"MobilenetV2/expanded_conv_1/depthwise_output" [label="MobilenetV2/expanded_conv_1/depthwise_output"]
# 	"MobilenetV2/expanded_conv_1/depthwise/Relu6" -> "MobilenetV2/expanded_conv_1/depthwise_output"
# 	"MobilenetV2/expanded_conv_1/project/weights" [label="MobilenetV2/expanded_conv_1/project/weights"]
# 	"MobilenetV2/expanded_conv_1/project/weights/read" [label="MobilenetV2/expanded_conv_1/project/weights/read"]
# 	"MobilenetV2/expanded_conv_1/project/weights" -> "MobilenetV2/expanded_conv_1/project/weights/read"
# 	"MobilenetV2/expanded_conv_1/project/Conv2D" [label="MobilenetV2/expanded_conv_1/project/Conv2D"]
# 	"MobilenetV2/expanded_conv_1/depthwise_output" -> "MobilenetV2/expanded_conv_1/project/Conv2D"
# 	"MobilenetV2/expanded_conv_1/project/weights/read" -> "MobilenetV2/expanded_conv_1/project/Conv2D"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/beta" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/beta" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_1/project/Conv2D" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_1/project/Identity" [label="MobilenetV2/expanded_conv_1/project/Identity"]
# 	"MobilenetV2/expanded_conv_1/project/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_1/project/Identity"
# 	"MobilenetV2/expanded_conv_1/output" [label="MobilenetV2/expanded_conv_1/output"]
# 	"MobilenetV2/expanded_conv_1/project/Identity" -> "MobilenetV2/expanded_conv_1/output"
# 	"MobilenetV2/expanded_conv_2/input" [label="MobilenetV2/expanded_conv_2/input"]
# 	"MobilenetV2/expanded_conv_1/output" -> "MobilenetV2/expanded_conv_2/input"
# 	"MobilenetV2/expanded_conv_2/expand/weights" [label="MobilenetV2/expanded_conv_2/expand/weights"]
# 	"MobilenetV2/expanded_conv_2/expand/weights/read" [label="MobilenetV2/expanded_conv_2/expand/weights/read"]
# 	"MobilenetV2/expanded_conv_2/expand/weights" -> "MobilenetV2/expanded_conv_2/expand/weights/read"
# 	"MobilenetV2/expanded_conv_2/expand/Conv2D" [label="MobilenetV2/expanded_conv_2/expand/Conv2D"]
# 	"MobilenetV2/expanded_conv_2/input" -> "MobilenetV2/expanded_conv_2/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_2/expand/weights/read" -> "MobilenetV2/expanded_conv_2/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/beta" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/beta" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_2/expand/Conv2D" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/expand/Relu6" [label="MobilenetV2/expanded_conv_2/expand/Relu6"]
# 	"MobilenetV2/expanded_conv_2/expand/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_2/expand/Relu6"
# 	"MobilenetV2/expanded_conv_2/expansion_output" [label="MobilenetV2/expanded_conv_2/expansion_output"]
# 	"MobilenetV2/expanded_conv_2/expand/Relu6" -> "MobilenetV2/expanded_conv_2/expansion_output"
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise_weights" [label="MobilenetV2/expanded_conv_2/depthwise/depthwise_weights"]
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/read" [label="MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/read"]
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise_weights" -> "MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/read"
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise" [label="MobilenetV2/expanded_conv_2/depthwise/depthwise"]
# 	"MobilenetV2/expanded_conv_2/expansion_output" -> "MobilenetV2/expanded_conv_2/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise_weights/read" -> "MobilenetV2/expanded_conv_2/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_2/depthwise/depthwise" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/depthwise/Relu6" [label="MobilenetV2/expanded_conv_2/depthwise/Relu6"]
# 	"MobilenetV2/expanded_conv_2/depthwise/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_2/depthwise/Relu6"
# 	"MobilenetV2/expanded_conv_2/depthwise_output" [label="MobilenetV2/expanded_conv_2/depthwise_output"]
# 	"MobilenetV2/expanded_conv_2/depthwise/Relu6" -> "MobilenetV2/expanded_conv_2/depthwise_output"
# 	"MobilenetV2/expanded_conv_2/project/weights" [label="MobilenetV2/expanded_conv_2/project/weights"]
# 	"MobilenetV2/expanded_conv_2/project/weights/read" [label="MobilenetV2/expanded_conv_2/project/weights/read"]
# 	"MobilenetV2/expanded_conv_2/project/weights" -> "MobilenetV2/expanded_conv_2/project/weights/read"
# 	"MobilenetV2/expanded_conv_2/project/Conv2D" [label="MobilenetV2/expanded_conv_2/project/Conv2D"]
# 	"MobilenetV2/expanded_conv_2/depthwise_output" -> "MobilenetV2/expanded_conv_2/project/Conv2D"
# 	"MobilenetV2/expanded_conv_2/project/weights/read" -> "MobilenetV2/expanded_conv_2/project/Conv2D"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/beta" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/beta" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_2/project/Conv2D" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_2/project/Identity" [label="MobilenetV2/expanded_conv_2/project/Identity"]
# 	"MobilenetV2/expanded_conv_2/project/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_2/project/Identity"
# 	"MobilenetV2/expanded_conv_2/add" [label="MobilenetV2/expanded_conv_2/add"]
# 	"MobilenetV2/expanded_conv_2/input" -> "MobilenetV2/expanded_conv_2/add"
# 	"MobilenetV2/expanded_conv_2/project/Identity" -> "MobilenetV2/expanded_conv_2/add"
# 	"MobilenetV2/expanded_conv_2/output" [label="MobilenetV2/expanded_conv_2/output"]
# 	"MobilenetV2/expanded_conv_2/add" -> "MobilenetV2/expanded_conv_2/output"
# 	"MobilenetV2/expanded_conv_3/input" [label="MobilenetV2/expanded_conv_3/input"]
# 	"MobilenetV2/expanded_conv_2/output" -> "MobilenetV2/expanded_conv_3/input"
# 	"MobilenetV2/expanded_conv_3/expand/weights" [label="MobilenetV2/expanded_conv_3/expand/weights"]
# 	"MobilenetV2/expanded_conv_3/expand/weights/read" [label="MobilenetV2/expanded_conv_3/expand/weights/read"]
# 	"MobilenetV2/expanded_conv_3/expand/weights" -> "MobilenetV2/expanded_conv_3/expand/weights/read"
# 	"MobilenetV2/expanded_conv_3/expand/Conv2D" [label="MobilenetV2/expanded_conv_3/expand/Conv2D"]
# 	"MobilenetV2/expanded_conv_3/input" -> "MobilenetV2/expanded_conv_3/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_3/expand/weights/read" -> "MobilenetV2/expanded_conv_3/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/beta" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/beta" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_3/expand/Conv2D" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/expand/Relu6" [label="MobilenetV2/expanded_conv_3/expand/Relu6"]
# 	"MobilenetV2/expanded_conv_3/expand/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_3/expand/Relu6"
# 	"MobilenetV2/expanded_conv_3/expansion_output" [label="MobilenetV2/expanded_conv_3/expansion_output"]
# 	"MobilenetV2/expanded_conv_3/expand/Relu6" -> "MobilenetV2/expanded_conv_3/expansion_output"
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise_weights" [label="MobilenetV2/expanded_conv_3/depthwise/depthwise_weights"]
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/read" [label="MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/read"]
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise_weights" -> "MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/read"
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise" [label="MobilenetV2/expanded_conv_3/depthwise/depthwise"]
# 	"MobilenetV2/expanded_conv_3/expansion_output" -> "MobilenetV2/expanded_conv_3/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise_weights/read" -> "MobilenetV2/expanded_conv_3/depthwise/depthwise"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_3/depthwise/depthwise" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/depthwise/Relu6" [label="MobilenetV2/expanded_conv_3/depthwise/Relu6"]
# 	"MobilenetV2/expanded_conv_3/depthwise/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_3/depthwise/Relu6"
# 	"MobilenetV2/expanded_conv_3/depthwise_output" [label="MobilenetV2/expanded_conv_3/depthwise_output"]
# 	"MobilenetV2/expanded_conv_3/depthwise/Relu6" -> "MobilenetV2/expanded_conv_3/depthwise_output"
# 	"MobilenetV2/expanded_conv_3/project/weights" [label="MobilenetV2/expanded_conv_3/project/weights"]
# 	"MobilenetV2/expanded_conv_3/project/weights/read" [label="MobilenetV2/expanded_conv_3/project/weights/read"]
# 	"MobilenetV2/expanded_conv_3/project/weights" -> "MobilenetV2/expanded_conv_3/project/weights/read"
# 	"MobilenetV2/expanded_conv_3/project/Conv2D" [label="MobilenetV2/expanded_conv_3/project/Conv2D"]
# 	"MobilenetV2/expanded_conv_3/depthwise_output" -> "MobilenetV2/expanded_conv_3/project/Conv2D"
# 	"MobilenetV2/expanded_conv_3/project/weights/read" -> "MobilenetV2/expanded_conv_3/project/Conv2D"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/beta" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/beta" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_3/project/Conv2D" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_3/project/Identity" [label="MobilenetV2/expanded_conv_3/project/Identity"]
# 	"MobilenetV2/expanded_conv_3/project/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_3/project/Identity"
# 	"MobilenetV2/expanded_conv_3/output" [label="MobilenetV2/expanded_conv_3/output"]
# 	"MobilenetV2/expanded_conv_3/project/Identity" -> "MobilenetV2/expanded_conv_3/output"
# 	"MobilenetV2/expanded_conv_4/input" [label="MobilenetV2/expanded_conv_4/input"]
# 	"MobilenetV2/expanded_conv_3/output" -> "MobilenetV2/expanded_conv_4/input"
# 	"MobilenetV2/expanded_conv_4/expand/weights" [label="MobilenetV2/expanded_conv_4/expand/weights"]
# 	"MobilenetV2/expanded_conv_4/expand/weights/read" [label="MobilenetV2/expanded_conv_4/expand/weights/read"]
# 	"MobilenetV2/expanded_conv_4/expand/weights" -> "MobilenetV2/expanded_conv_4/expand/weights/read"
# 	"MobilenetV2/expanded_conv_4/expand/Conv2D" [label="MobilenetV2/expanded_conv_4/expand/Conv2D"]
# 	"MobilenetV2/expanded_conv_4/input" -> "MobilenetV2/expanded_conv_4/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_4/expand/weights/read" -> "MobilenetV2/expanded_conv_4/expand/Conv2D"
# 	"MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_4/expand/BatchNorm/gamma/read"]
# ...
# 	"MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND" [label="MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND"]
# 	"MobilenetV2/expanded_conv_16/depthwise/depthwise" -> "MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND"
# 	"MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/block_shape" -> "MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND"
# 	"MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND/crops" -> "MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_16/depthwise/depthwise/BatchToSpaceND" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/depthwise/Relu6" [label="MobilenetV2/expanded_conv_16/depthwise/Relu6"]
# 	"MobilenetV2/expanded_conv_16/depthwise/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_16/depthwise/Relu6"
# 	"MobilenetV2/expanded_conv_16/depthwise_output" [label="MobilenetV2/expanded_conv_16/depthwise_output"]
# 	"MobilenetV2/expanded_conv_16/depthwise/Relu6" -> "MobilenetV2/expanded_conv_16/depthwise_output"
# 	"MobilenetV2/expanded_conv_16/project/weights" [label="MobilenetV2/expanded_conv_16/project/weights"]
# 	"MobilenetV2/expanded_conv_16/project/weights/read" [label="MobilenetV2/expanded_conv_16/project/weights/read"]
# 	"MobilenetV2/expanded_conv_16/project/weights" -> "MobilenetV2/expanded_conv_16/project/weights/read"
# 	"MobilenetV2/expanded_conv_16/project/Conv2D" [label="MobilenetV2/expanded_conv_16/project/Conv2D"]
# 	"MobilenetV2/expanded_conv_16/depthwise_output" -> "MobilenetV2/expanded_conv_16/project/Conv2D"
# 	"MobilenetV2/expanded_conv_16/project/weights/read" -> "MobilenetV2/expanded_conv_16/project/Conv2D"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/gamma" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/gamma"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/gamma" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/beta" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/beta"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/beta" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm" [label="MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"]
# 	"MobilenetV2/expanded_conv_16/project/Conv2D" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/gamma/read" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/beta/read" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_mean/read" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/moving_variance/read" -> "MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm"
# 	"MobilenetV2/expanded_conv_16/project/Identity" [label="MobilenetV2/expanded_conv_16/project/Identity"]
# 	"MobilenetV2/expanded_conv_16/project/BatchNorm/FusedBatchNorm" -> "MobilenetV2/expanded_conv_16/project/Identity"
# 	"MobilenetV2/expanded_conv_16/output" [label="MobilenetV2/expanded_conv_16/output"]
# 	"MobilenetV2/expanded_conv_16/project/Identity" -> "MobilenetV2/expanded_conv_16/output"
# 	"AvgPool2D/AvgPool" [label="AvgPool2D/AvgPool"]
# 	"MobilenetV2/expanded_conv_16/output" -> "AvgPool2D/AvgPool"
# 	"image_pooling/weights" [label="image_pooling/weights"]
# 	"image_pooling/weights/read" [label="image_pooling/weights/read"]
# 	"image_pooling/weights" -> "image_pooling/weights/read"
# 	"image_pooling/Conv2D" [label="image_pooling/Conv2D"]
# 	"AvgPool2D/AvgPool" -> "image_pooling/Conv2D"
# 	"image_pooling/weights/read" -> "image_pooling/Conv2D"
# 	"image_pooling/BatchNorm/gamma" [label="image_pooling/BatchNorm/gamma"]
# 	"image_pooling/BatchNorm/gamma/read" [label="image_pooling/BatchNorm/gamma/read"]
# 	"image_pooling/BatchNorm/gamma" -> "image_pooling/BatchNorm/gamma/read"
# 	"image_pooling/BatchNorm/beta" [label="image_pooling/BatchNorm/beta"]
# 	"image_pooling/BatchNorm/beta/read" [label="image_pooling/BatchNorm/beta/read"]
# 	"image_pooling/BatchNorm/beta" -> "image_pooling/BatchNorm/beta/read"
# 	"image_pooling/BatchNorm/moving_mean" [label="image_pooling/BatchNorm/moving_mean"]
# 	"image_pooling/BatchNorm/moving_mean/read" [label="image_pooling/BatchNorm/moving_mean/read"]
# 	"image_pooling/BatchNorm/moving_mean" -> "image_pooling/BatchNorm/moving_mean/read"
# 	"image_pooling/BatchNorm/moving_variance" [label="image_pooling/BatchNorm/moving_variance"]
# 	"image_pooling/BatchNorm/moving_variance/read" [label="image_pooling/BatchNorm/moving_variance/read"]
# 	"image_pooling/BatchNorm/moving_variance" -> "image_pooling/BatchNorm/moving_variance/read"
# 	"image_pooling/BatchNorm/FusedBatchNorm" [label="image_pooling/BatchNorm/FusedBatchNorm"]
# 	"image_pooling/Conv2D" -> "image_pooling/BatchNorm/FusedBatchNorm"
# 	"image_pooling/BatchNorm/gamma/read" -> "image_pooling/BatchNorm/FusedBatchNorm"
# 	"image_pooling/BatchNorm/beta/read" -> "image_pooling/BatchNorm/FusedBatchNorm"
# 	"image_pooling/BatchNorm/moving_mean/read" -> "image_pooling/BatchNorm/FusedBatchNorm"
# 	"image_pooling/BatchNorm/moving_variance/read" -> "image_pooling/BatchNorm/FusedBatchNorm"
# 	"image_pooling/Relu" [label="image_pooling/Relu"]
# 	"image_pooling/BatchNorm/FusedBatchNorm" -> "image_pooling/Relu"
# 	"ResizeBilinear_1/size" [label="ResizeBilinear_1/size"]
# 	ResizeBilinear_1 [label=ResizeBilinear_1]
# 	"image_pooling/Relu" -> ResizeBilinear_1
# 	"ResizeBilinear_1/size" -> ResizeBilinear_1
# 	"aspp0/weights" [label="aspp0/weights"]
# 	"aspp0/weights/read" [label="aspp0/weights/read"]
# 	"aspp0/weights" -> "aspp0/weights/read"
# 	"aspp0/Conv2D" [label="aspp0/Conv2D"]
# 	"MobilenetV2/expanded_conv_16/output" -> "aspp0/Conv2D"
# 	"aspp0/weights/read" -> "aspp0/Conv2D"
# 	"aspp0/BatchNorm/gamma" [label="aspp0/BatchNorm/gamma"]
# 	"aspp0/BatchNorm/gamma/read" [label="aspp0/BatchNorm/gamma/read"]
# 	"aspp0/BatchNorm/gamma" -> "aspp0/BatchNorm/gamma/read"
# 	"aspp0/BatchNorm/beta" [label="aspp0/BatchNorm/beta"]
# 	"aspp0/BatchNorm/beta/read" [label="aspp0/BatchNorm/beta/read"]
# 	"aspp0/BatchNorm/beta" -> "aspp0/BatchNorm/beta/read"
# 	"aspp0/BatchNorm/moving_mean" [label="aspp0/BatchNorm/moving_mean"]
# 	"aspp0/BatchNorm/moving_mean/read" [label="aspp0/BatchNorm/moving_mean/read"]
# 	"aspp0/BatchNorm/moving_mean" -> "aspp0/BatchNorm/moving_mean/read"
# 	"aspp0/BatchNorm/moving_variance" [label="aspp0/BatchNorm/moving_variance"]
# 	"aspp0/BatchNorm/moving_variance/read" [label="aspp0/BatchNorm/moving_variance/read"]
# 	"aspp0/BatchNorm/moving_variance" -> "aspp0/BatchNorm/moving_variance/read"
# 	"aspp0/BatchNorm/FusedBatchNorm" [label="aspp0/BatchNorm/FusedBatchNorm"]
# 	"aspp0/Conv2D" -> "aspp0/BatchNorm/FusedBatchNorm"
# 	"aspp0/BatchNorm/gamma/read" -> "aspp0/BatchNorm/FusedBatchNorm"
# 	"aspp0/BatchNorm/beta/read" -> "aspp0/BatchNorm/FusedBatchNorm"
# 	"aspp0/BatchNorm/moving_mean/read" -> "aspp0/BatchNorm/FusedBatchNorm"
# 	"aspp0/BatchNorm/moving_variance/read" -> "aspp0/BatchNorm/FusedBatchNorm"
# 	"aspp0/Relu" [label="aspp0/Relu"]
# 	"aspp0/BatchNorm/FusedBatchNorm" -> "aspp0/Relu"
# 	"concat/axis" [label="concat/axis"]
# 	concat [label=concat]
# 	ResizeBilinear_1 -> concat
# 	"aspp0/Relu" -> concat
# 	"concat/axis" -> concat
# 	"concat_projection/weights" [label="concat_projection/weights"]
# 	"concat_projection/weights/read" [label="concat_projection/weights/read"]
# 	"concat_projection/weights" -> "concat_projection/weights/read"
# 	"concat_projection/Conv2D" [label="concat_projection/Conv2D"]
# 	concat -> "concat_projection/Conv2D"
# 	"concat_projection/weights/read" -> "concat_projection/Conv2D"
# 	"concat_projection/BatchNorm/gamma" [label="concat_projection/BatchNorm/gamma"]
# 	"concat_projection/BatchNorm/gamma/read" [label="concat_projection/BatchNorm/gamma/read"]
# 	"concat_projection/BatchNorm/gamma" -> "concat_projection/BatchNorm/gamma/read"
# 	"concat_projection/BatchNorm/beta" [label="concat_projection/BatchNorm/beta"]
# 	"concat_projection/BatchNorm/beta/read" [label="concat_projection/BatchNorm/beta/read"]
# 	"concat_projection/BatchNorm/beta" -> "concat_projection/BatchNorm/beta/read"
# 	"concat_projection/BatchNorm/moving_mean" [label="concat_projection/BatchNorm/moving_mean"]
# 	"concat_projection/BatchNorm/moving_mean/read" [label="concat_projection/BatchNorm/moving_mean/read"]
# 	"concat_projection/BatchNorm/moving_mean" -> "concat_projection/BatchNorm/moving_mean/read"
# 	"concat_projection/BatchNorm/moving_variance" [label="concat_projection/BatchNorm/moving_variance"]
# 	"concat_projection/BatchNorm/moving_variance/read" [label="concat_projection/BatchNorm/moving_variance/read"]
# 	"concat_projection/BatchNorm/moving_variance" -> "concat_projection/BatchNorm/moving_variance/read"
# 	"concat_projection/BatchNorm/FusedBatchNorm" [label="concat_projection/BatchNorm/FusedBatchNorm"]
# 	"concat_projection/Conv2D" -> "concat_projection/BatchNorm/FusedBatchNorm"
# 	"concat_projection/BatchNorm/gamma/read" -> "concat_projection/BatchNorm/FusedBatchNorm"
# 	"concat_projection/BatchNorm/beta/read" -> "concat_projection/BatchNorm/FusedBatchNorm"
# 	"concat_projection/BatchNorm/moving_mean/read" -> "concat_projection/BatchNorm/FusedBatchNorm"
# 	"concat_projection/BatchNorm/moving_variance/read" -> "concat_projection/BatchNorm/FusedBatchNorm"
# 	"concat_projection/Relu" [label="concat_projection/Relu"]
# 	"concat_projection/BatchNorm/FusedBatchNorm" -> "concat_projection/Relu"
# 	"concat_projection_dropout/Identity" [label="concat_projection_dropout/Identity"]
# 	"concat_projection/Relu" -> "concat_projection_dropout/Identity"
# 	"logits/semantic/weights" [label="logits/semantic/weights"]
# 	"logits/semantic/weights/read" [label="logits/semantic/weights/read"]
# 	"logits/semantic/weights" -> "logits/semantic/weights/read"
# 	"logits/semantic/biases" [label="logits/semantic/biases"]
# 	"logits/semantic/biases/read" [label="logits/semantic/biases/read"]
# 	"logits/semantic/biases" -> "logits/semantic/biases/read"
# 	"logits/semantic/Conv2D" [label="logits/semantic/Conv2D"]
# 	"concat_projection_dropout/Identity" -> "logits/semantic/Conv2D"
# 	"logits/semantic/weights/read" -> "logits/semantic/Conv2D"
# 	"logits/semantic/BiasAdd" [label="logits/semantic/BiasAdd"]
# 	"logits/semantic/Conv2D" -> "logits/semantic/BiasAdd"
# 	"logits/semantic/biases/read" -> "logits/semantic/BiasAdd"
# 	"ResizeBilinear_2/size" [label="ResizeBilinear_2/size"]
# 	ResizeBilinear_2 [label=ResizeBilinear_2]
# 	"logits/semantic/BiasAdd" -> ResizeBilinear_2
# 	"ResizeBilinear_2/size" -> ResizeBilinear_2
# 	Shape_4 [label=Shape_4]
# 	"strided_slice_7/stack" [label="strided_slice_7/stack"]
# 	"strided_slice_7/stack_1" [label="strided_slice_7/stack_1"]
# 	"strided_slice_7/stack_2" [label="strided_slice_7/stack_2"]
# 	strided_slice_7 [label=strided_slice_7]
# 	Shape_4 -> strided_slice_7
# 	"strided_slice_7/stack" -> strided_slice_7
# 	"strided_slice_7/stack_1" -> strided_slice_7
# 	"strided_slice_7/stack_2" -> strided_slice_7
# 	ResizeBilinear_3 [label=ResizeBilinear_3]
# 	ResizeBilinear_2 -> ResizeBilinear_3
# 	strided_slice_7 -> ResizeBilinear_3
# 	"ArgMax/dimension" [label="ArgMax/dimension"]
# 	ArgMax [label=ArgMax]
# 	ResizeBilinear_3 -> ArgMax
# 	"ArgMax/dimension" -> ArgMax
# 	"strided_slice_8/stack" [label="strided_slice_8/stack"]
# 	"strided_slice_8/stack_1" [label="strided_slice_8/stack_1"]
# 	"strided_slice_8/stack_2" [label="strided_slice_8/stack_2"]
# 	strided_slice_8 [label=strided_slice_8]
# 	strided_slice -> strided_slice_8
# 	"strided_slice_8/stack" -> strided_slice_8
# 	"strided_slice_8/stack_1" -> strided_slice_8
# 	"strided_slice_8/stack_2" -> strided_slice_8
# 	"strided_slice_9/stack" [label="strided_slice_9/stack"]
# 	"strided_slice_9/stack_1" [label="strided_slice_9/stack_1"]
# 	"strided_slice_9/stack_2" [label="strided_slice_9/stack_2"]
# 	strided_slice_9 [label=strided_slice_9]
# 	strided_slice -> strided_slice_9
# 	"strided_slice_9/stack" -> strided_slice_9
# 	"strided_slice_9/stack_1" -> strided_slice_9
# 	"strided_slice_9/stack_2" -> strided_slice_9
# 	"SemanticPredictions/begin" [label="SemanticPredictions/begin"]
# 	"SemanticPredictions/size/0" [label="SemanticPredictions/size/0"]
# 	"SemanticPredictions/size" [label="SemanticPredictions/size"]
# 	"SemanticPredictions/size/0" -> "SemanticPredictions/size"
# 	strided_slice_8 -> "SemanticPredictions/size"
# 	strided_slice_9 -> "SemanticPredictions/size"
# 	SemanticPredictions [label=SemanticPredictions]
# 	ArgMax -> SemanticPredictions
# 	"SemanticPredictions/begin" -> SemanticPredictions
# 	"SemanticPredictions/size" -> SemanticPredictions
# }
# model loaded successfully!

# %% [markdown]
# ## Run on sample images
#
# Select one of sample images (leave `IMAGE_URL` empty) or feed any internet image
# url for inference.
#
# Note that we are using single scale inference in the demo for fast computation,
# so the results may slightly differ from the visualizations in
# [README](https://github.com/tensorflow/models/blob/master/research/deeplab/README.md),
# which uses multi-scale and left-right flipped inputs.

# %%
#@title Run on sample images {display-mode: "form"}

SAMPLE_IMAGE = 'image1'  # @param ['image1', 'image2', 'image3']
IMAGE_URL = ''  #@param {type:"string"}

_SAMPLE_URL = ('https://github.com/tensorflow/models/blob/master/research/'
               'deeplab/g3doc/img/%s.jpg?raw=true')


def run_visualization(url):
  """Inferences DeepLab model and visualizes result."""
  try:
    f = urllib.request.urlopen(url)
    jpeg_str = f.read()
    original_im = Image.open(BytesIO(jpeg_str))
  except IOError:
    print('Cannot retrieve image. Please check url: ' + url)
    return

  print('running deeplab on image %s...' % url)
  resized_im, seg_map = MODEL.run(original_im)

  vis_segmentation(resized_im, seg_map)


image_url = IMAGE_URL or _SAMPLE_URL % SAMPLE_IMAGE
run_visualization(image_url)
# Out:
# running deeplab on image https://github.com/tensorflow/models/blob/master/research/deeplab/g3doc/img/image1.jpg?raw=true...
# (640, 427)
# (342, 513)
